# %%
import yfinance as yf
from statsmodels.tsa.stattools import coint

def check_cointegration(ticker1, ticker2, start_date, end_date, alpha=0.05):
    # Download the adjusted close prices for the given tickers
    data = yf.download([ticker1, ticker2], start=start_date, end=end_date)['Adj Close']
    
    # Calculate the cointegration between the two tickers
    series1 = data[ticker1]
    series2 = data[ticker2]
    
    # Perform the cointegration test
    score, p_value, _ = coint(series1, series2)
    
    # Display the results
    print(f'Cointegration test score: {score}')
    print(f'p-value: {p_value}')
    
    # Evaluate the statistical significance
    if p_value < alpha:
        print(f'The result is statistically significant. {ticker1} and {ticker2} are cointegrated.')
    else:
        print(f'The result is not statistically significant. {ticker1} and {ticker2} are not cointegrated.')

# %%
import itertools

# List of stock pairs
stock_pairs = [
    ('KO', 'PEP'), # Coca-Cola & Pepsi
    ('XOM', 'CVX'), # Exxon Mobil & Chevron
    ('T', 'VZ'), # AT&T & Verizon
    ('MCD', 'YUM'), # McDonald's & Yum! Brands
    ('JNJ', 'PG'), # Johnson & Johnson & Procter & Gamble
    ('WMT', 'TGT'), # Walmart & Target
    ('AAPL', 'MSFT'), # Apple & Microsoft
    ('IBM', 'ORCL'), # IBM & Oracle
    ('BA', 'AIR'), # Boeing & Airbus
    ('NFLX', 'DIS'), # Netflix & Disney
    ('JNJ', 'PFE'), # Johnson & Johnson & Pfizer
    ('V', 'MA'), # Visa & Mastercard
    ('PG', 'CL'), # Procter & Gamble & Colgate-Palmolive
    ('HD', 'LOW'), # Home Depot & Lowe's
    ('WMT', 'COST'), # Walmart & Costco
    ('MCD', 'SBUX'), # McDonald's & Starbucks
    ('BA', 'LMT'), # Boeing & Lockheed Martin
    ('CVX', 'XOM'), # Chevron & Exxon Mobil
    ('GE', 'SIEGY'), # General Electric & Siemens AG
    ('INTC', 'AMD'), # Intel & AMD
    ('NKE', 'ADDYY'), # Nike & Adidas
    ('CAT', 'DE') # Caterpillar & Deere & Co.
                ]


# Specify date range
start_date = '2010-05-29'
end_date = '2024-05-29'

# Check cointegration for each pair
for pair in stock_pairs:
    stock1, stock2 = pair
    result = check_cointegration(stock1, stock2, start_date, end_date)
# Out:
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -4.906314637682221
# p-value: 0.00024387677581675155
# The result is statistically significant. KO and PEP are cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -1.4654082276353844
# p-value: 0.7742161772825032
# The result is not statistically significant. XOM and CVX are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -2.9618315475883428
# p-value: 0.11955919038633667
# The result is not statistically significant. T and VZ are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -4.188780973877835
# p-value: 0.0037932184520180394
# The result is statistically significant. MCD and YUM are cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -1.8571781267383114
# p-value: 0.6015564889420164
# The result is not statistically significant. JNJ and PG are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -0.460913284458814
# p-value: 0.9670006895608266
# The result is not statistically significant. WMT and TGT are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -2.4962343235175672
# p-value: 0.280732323930117
# The result is not statistically significant. AAPL and MSFT are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -3.082365364188424
# p-value: 0.09189989761499728
# The result is not statistically significant. IBM and ORCL are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -1.0551326947411546
# p-value: 0.8918819511357075
# The result is not statistically significant. BA and AIR are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -0.8642674273267167
# p-value: 0.9257180570699886
# The result is not statistically significant. NFLX and DIS are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -2.199068542494059
# p-value: 0.4248438975284563
# The result is not statistically significant. JNJ and PFE are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -3.3670108434574106
# p-value: 0.04614894834121489
# The result is statistically significant. V and MA are cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -2.002803691328807
# p-value: 0.527120362707093
# The result is not statistically significant. PG and CL are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -2.8338087405693324
# p-value: 0.15516424117063332
# The result is not statistically significant. HD and LOW are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -2.7672144098963622
# p-value: 0.1763395220300768
# The result is not statistically significant. WMT and COST are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -1.6887978493565796
# p-value: 0.6820017103020457
# The result is not statistically significant. MCD and SBUX are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -1.6565237886199926
# p-value: 0.6964536200358219
# The result is not statistically significant. BA and LMT are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -1.9101397317751592
# p-value: 0.5748553389979275
# The result is not statistically significant. CVX and XOM are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -0.4635920654531929
# p-value: 0.9668248441989258
# The result is not statistically significant. GE and SIEGY are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -1.5297541594545412
# p-value: 0.749606677433077
# The result is not statistically significant. INTC and AMD are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: -1.6124881896609593
# p-value: 0.7155901375893461
# The result is not statistically significant. NKE and ADDYY are not cointegrated.
# [*********************100%%**********************]  2 of 2 completed
# Cointegration test score: 0.15893169500099769
# p-value: 0.9889828338724687
# The result is not statistically significant. CAT and DE are not cointegrated.
